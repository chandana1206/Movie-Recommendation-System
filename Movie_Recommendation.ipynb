# %%
import pandas as pd
import numpy as np

# %%
credits_df= pd.read_csv('credits.csv')
movieslist_df= pd.read_csv('movies.csv')

# %%
credits_df.shape
# Out:
# (4803, 4)

# %%
credits_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movieslist_df.shape
# Out:
# (4803, 20)

# %%
movieslist_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_df = pd.merge(movieslist_df, credits_df, on='title', how='inner')

# %%
movies_df.shape
# Out:
# (4808, 23)

# %%
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_df = movies_df[['title', 'genres', 'overview', 'vote_average', 'cast', 'crew']]

# %%
movies_df.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             overview  vote_average  \
# 0  In the 22nd century, a paraplegic Marine is di...           7.2
# 1  Captain Barbossa, long believed to be dead, ha...           6.9
# 2  A cryptic message from Bond’s past sends him o...           6.3
# 3  Following the death of District Attorney Harve...           7.6
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4808 entries, 0 to 4807
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         4808 non-null   object
#  1   genres        4808 non-null   object
#  2   overview      4805 non-null   object
#  3   vote_average  4808 non-null   float64
#  4   cast          4808 non-null   object
#  5   crew          4808 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 225.5+ KB

# %%
movies_df.describe()
# Out:
#        vote_average
# count   4808.000000
# mean       6.092824
# std        1.193919
# min        0.000000
# 25%        5.600000
# 50%        6.200000
# 75%        6.800000
# max       10.000000

# %% [markdown]
# DATA CLEANING

# %%
movies_df.isnull().sum()
# Out:
# title           0
# genres          0
# overview        3
# vote_average    0
# cast            0
# crew            0
# dtype: int64

# %%
movies_df.dropna(inplace=True)

# %%
movies_df.isnull().sum()
# Out:
# title           0
# genres          0
# overview        0
# vote_average    0
# cast            0
# crew            0
# dtype: int64

# %%
movies_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies_df.iloc[0]
# Out:
# title                                                      Avatar
# genres          [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# overview        In the 22nd century, a paraplegic Marine is di...
# vote_average                                                  7.2
# cast            [{"cast_id": 242, "character": "Jake Sully", "...
# crew            [{"credit_id": "52fe48009251416c750aca23", "de...
# Name: 0, dtype: object

# %%
# Convert genres, cast, and crew Columns into lists
import ast

def extract_genres(x):
    genres = []
    if x:
        for i in ast.literal_eval(x):
            genres.append(i['name'])
    return genres

def extract_cast(x):
    cast = []
    if x:
        for i in ast.literal_eval(x)[:3]:  # Top 3 actors
            cast.append(i['name'])
    return cast

def extract_director(x):
    directors = []
    if x:
        for i in ast.literal_eval(x):
            if i['job'] == 'Director':
                directors.append(i['name'])
    return directors

# %%
movies_df['genres'] = movies_df['genres'].apply(extract_genres)
movies_df['cast'] = movies_df['cast'].apply(extract_cast)
movies_df['crew'] = movies_df['crew'].apply(extract_director)

# %%
movies_df = movies_df.rename(columns={'crew': 'director'})
movies_df = movies_df.rename(columns={'vote_average': 'votes'})

# %%
# Convert 'genres' and 'cast' columns to strings if they're in list format
movies_df['genres'] = movies_df['genres'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
movies_df['cast'] = movies_df['cast'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
movies_df['director'] = movies_df['director'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)

# %%
# Convert all columns with string data to lowercase
movies_df = movies_df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2796\257969576.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   movies_df = movies_df.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %%
movies_df.head()
# Out:
#                                       title  \
# 0                                    avatar
# 1  pirates of the caribbean: at world's end
# 2                                   spectre
# 3                     the dark knight rises
# 4                               john carter
#
#                                      genres  \
# 0  action adventure fantasy science fiction
# 1                  adventure fantasy action
# 2                    action adventure crime
# 3               action crime drama thriller
# 4          action adventure science fiction
#
#                                             overview  votes  \
# 0  in the 22nd century, a paraplegic marine is di...    7.2
# 1  captain barbossa, long believed to be dead, ha...    6.9
# 2  a cryptic message from bond’s past sends him o...    6.3
# 3  following the death of district attorney harve...    7.6
# 4  john carter is a war-weary, former military ca...    6.1
#
# ...

# %%
# Combine 'overview', 'genres', 'cast', and 'director' into a single 'combined' column
movies_df['tags'] = (
    movies_df['overview'].fillna('') + ' ' +
    movies_df['genres'].apply(lambda x: ' '.join(x)) + ' ' +
    movies_df['cast'].apply(lambda x: ' '.join(x)) + ' ' +
    movies_df['director'].apply(lambda x: ' '.join(x))
)

# %%
movies_df.head()
# Out:
#                                       title  \
# 0                                    avatar
# 1  pirates of the caribbean: at world's end
# 2                                   spectre
# 3                     the dark knight rises
# 4                               john carter
#
#                                      genres  \
# 0  action adventure fantasy science fiction
# 1                  adventure fantasy action
# 2                    action adventure crime
# 3               action crime drama thriller
# 4          action adventure science fiction
#
#                                             overview  votes  \
# 0  in the 22nd century, a paraplegic marine is di...    7.2
# 1  captain barbossa, long believed to be dead, ha...    6.9
# 2  a cryptic message from bond’s past sends him o...    6.3
# 3  following the death of district attorney harve...    7.6
# 4  john carter is a war-weary, former military ca...    6.1
#
# ...

# %%
import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
lemmatizer = WordNetLemmatizer()

# %%
import string

def lemmatization(tags):
    words = []
    for word in tags.split():
        # Lemmatize the word and remove punctuation
        word = word.strip(string.punctuation)
        words.append(lemmatizer.lemmatize(word))
    return ' '.join(words)

movies_df['tags'] = movies_df['tags'].apply(lemmatization)

# %%
# Term Frequency-Inverse Document Frequency 
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(stop_words='english') #removes common English words (like "the", "is", "in", etc.)

# Fit and transform the 'tags' column into numerical vectors
tfidf_matrix = vectorizer.fit_transform(movies_df['tags']).toarray()

# to see how many features we’ve got
tfidf_matrix.shape
# Out:
# (4805, 18915)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Calculate the cosine similarity matrix
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
def get_similar_movies(title, cosine_sim=cosine_sim):
    
    title = title.lower()

    # Find the index of the movie in the dataset, if it exists
    if title in movies_df['title'].str.lower().values:
        idx = movies_df[movies_df['title'].str.lower() == title].index[0]
    else:
        print("Movie not found in the dataset.")
        return
    
    # Get the similarity scores of all movies with the input movie
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Sort the movies based on similarity scores (highest first)
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the top 5 most similar movies (skip the first one, because it's the movie itself)
    top_movies = sim_scores[1:6]
    
    # Extract movie titles of the top 5 most similar movies
    for i in top_movies:
        print( movies_df['title'].iloc[i[0]])
# Out:
# ordinary people
# love me tender
# hanging up
# the good guy
# from a whisper to a scream

# %%
def get_top_movies_with(genre=None, actor=None, director=None, num_recs=10):
    # Start with all movies
    filtered_movies = movies_df

    # Filter by genre if provided
    if genre:
        filtered_movies = filtered_movies[filtered_movies['genres'].str.contains(genre.lower())]

    # Filter by actor if provided
    if actor:
        filtered_movies = filtered_movies[filtered_movies['cast'].str.contains(actor.lower())]

    # Filter by director if provided
    if director:
        filtered_movies = filtered_movies[filtered_movies['director'].str.contains(director.lower())]

    # If no movies are found after all filters, return an empty list
    if filtered_movies.shape[0] == 0:
        return "No Movies Found"

    # Sort by ratings in descending order
    filtered_movies = filtered_movies.sort_values(by='votes', ascending=False)

    # Return the top N movie titles
    return filtered_movies['title'].head(num_recs)

# %% [markdown]
# OUTPUTS

# %%
# get movie recommendations similar to the one provided
get_similar_movies("twilight")
# Out:
# the twilight saga: new moon
# the twilight saga: eclipse
# black swan
# edward scissorhands
# little boy

# %%
# get movie recommendations with given filter
get_top_movies_with(actor="tom cruise")
# Out:
# 74                          edge of tomorrow
# 1814                                rain man
# 156                         the last samurai
# 912               interview with the vampire
# 275                          minority report
# 1480                          a few good men
# 134       mission: impossible - rogue nation
# 650                           eyes wide shut
# 714                               collateral
# 153     mission: impossible - ghost protocol
# Name: title, dtype: object
